# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **loading the datasets**

# %%
weather=pd.read_csv("/kaggle/input/road-accidents-in-india-20142017/Acc_Classified_according_to_Type_of_Weather_Condition_2014_and_2016.csv")
road_type=pd.read_csv("/kaggle/input/road-accidents-in-india-20142017/Acc_clf_acco_to_Road_Cond_2014_and_2016.csv")
killed_data=pd.read_csv("/kaggle/input/road-accidents-in-india-20142017/Road_Accidents_2017-Annuxure_Tables_3.csv")
injured=pd.read_csv("/kaggle/input/road-accidents-in-india-20142017/Road_Accidents_2017-Annuxure_Tables_4.csv")

# %% [markdown]
# # > INJURED

# %% [markdown]
# **Checking the first five rows**

# %%
injured.head()
# Out:
#           States/UTs  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014  \
# 0                                              29931
# 1                                                308
# 2                                               6499
# 3                                               6640
# 4                                              13157
#
#    State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015  \
# 0                                              29439
# 1                                                359
# 2                                               7068
# 3                                               6835
# 4                                              13426
#
#    State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016  \
# ...

# %% [markdown]
# **checking the last five rows**

# %%
injured.tail()
# Out:
#      States/UTs  \
# 32  Daman & Diu
# 33        Delhi
# 34  Lakshadweep
# 35   Puducherry
# 36        Total
#
#     State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014  \
# 32                                                 49
# 33                                               8283
# 34                                                  1
# 35                                               1323
# 36                                             493474
#
#     State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015  \
# 32                                                 64
# 33                                               8258
# 34                                                  3
# 35                                               1552
# 36                                             500279
#
#     State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016  \
# 32                                                102
# ...

# %% [markdown]
# **checking the column names**

# %%
injured.columns
# Out:
# Index(['States/UTs',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2017',
#        'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2014',
#        'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2015',
#        'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2016',
#        'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2017',
#        'Total Number of Persons Injured in Road Accidents Per Lakh Population - 2014',
#        'Total Number of Persons Injured in Road Accidents Per Lakh Population - 2015',
# ...

# %% [markdown]
# **Number of rows and columns in the injured df**

# %%
injured.shape
# Out:
# (37, 19)

# %% [markdown]
# **Dropping the duplicates**

# %%
injured.drop_duplicates()
# Out:
#                    States/UTs  \
# 0              Andhra Pradesh
# 1           Arunachal Pradesh
# 2                       Assam
# 3                       Bihar
# 4                Chhattisgarh
# 5                         Goa
# 6                     Gujarat
# 7                     Haryana
# 8            Himachal Pradesh
# 9             Jammu & Kashmir
# 10                  Jharkhand
# 11                  Karnataka
# 12                     Kerala
# 13             Madhya Pradesh
# 14                Maharashtra
# 15                    Manipur
# 16                  Meghalaya
# 17                    Mizoram
# 18                   Nagaland
# 19                     Odisha
# 20                     Punjab
# 21                  Rajasthan
# 22                     Sikkim
# 23                 Tamil Nadu
# 24                  Telangana
# 25                    Tripura
# 26                Uttarakhand
# 27              Uttar Pradesh
# 28                West Bengal
# 29  Andaman & Nicobar Islands
# ...

# %%
injured.shape
# Out:
# (37, 19)

# %%
injured.nunique()
# Out:
# States/UTs                                                                         37
# State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014      37
# State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015      36
# State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016      37
# State/UT-wise Total Number of Persons Injured in Road Accidents during - 2017      37
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2014    26
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2015    24
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2016    24
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2017    25
# Total Number of Persons Injured in Road Accidents Per Lakh Population - 2014       36
# Total Number of Persons Injured in Road Accidents Per Lakh Population - 2015       34
# ...

# %%
injured['States/UTs'].values.tolist()
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttarakhand',
#  'Uttar Pradesh',
#  'West Bengal',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Lakshadweep',
#  'Puducherry',
#  'Total']

# %% [markdown]
# **Missing values**

# %%
injured.isnull().sum().sort_values(ascending=True)
# Out:
# States/UTs                                                                         0
# Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2014    0
# Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2016       0
# Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2015       0
# Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2014       0
# Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2015    0
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2017    0
# Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2016    0
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2015    0
# Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2014    0
# State/UT-wise Total Number of Persons Injured in Road Accidents during - 2017      0
# ...

# %%
injured = injured.drop(columns = ['Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2014',
       'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2015',
       'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2016',
       'Share of States/UTs in Total Number of Persons Injured in Road Accidents - 2017',
      ])

# %%
injured.shape
# Out:
# (37, 15)

# %% [markdown]
# **Description of injured df**

# %%
injured.describe()
# Out:
#        State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014  \
# count                                          37.000000
# mean                                        26674.270270
# std                                         81101.786738
# min                                             1.000000
# 25%                                           352.000000
# 50%                                          6499.000000
# 75%                                         22337.000000
# max                                        493474.000000
#
#        State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015  \
# count                                          37.000000
# mean                                        27042.108108
# std                                         82222.705770
# min                                             3.000000
# 25%                                           359.000000
# ...

# %% [markdown]
# **Extracting the Estimated Total Population**

# %%
# Columns for total number of persons killed and corresponding rates
death_columns = [
    'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014',
       'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015',
       'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016',
       'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2017'
]
 
population_columns = ['Total Number of Persons Injured in Road Accidents Per Lakh Population - 2014',
       'Total Number of Persons Injured in Road Accidents Per Lakh Population - 2015',
       'Total Number of Persons Injured in Road Accidents Per Lakh Population - 2016',
       'Total Number of Persons Injured in Road Accidents Per Lakh Population - 2017'
   
]
 
# Calculate estimated total population for each year
for i, death_column in enumerate(death_columns):
    population_column = population_columns[i]
    estimated_population_column = f'Estimated Total Population - {death_column[-4:]}'
    injured[estimated_population_column] = (
        injured[death_column] /injured[population_column] * 100000
    )
 
# Drop the original estimated total population columns
injured.drop(columns=population_columns, inplace=True)
 
# Display the updated DataFrame
injured.head()
# Out:
#           States/UTs  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014  \
# 0                                              29931
# 1                                                308
# 2                                               6499
# 3                                               6640
# 4                                              13157
#
#    State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015  \
# 0                                              29439
# 1                                                359
# 2                                               7068
# 3                                               6835
# 4                                              13426
#
#    State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016  \
# ...

# %%
injured.columns
# Out:
# Index(['States/UTs',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016',
#        'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2017',
#        'Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2014',
#        'Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2015',
#        'Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2016',
#        'Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2014',
#        'Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2015',
#        'Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2016',
#        'Estimated Total Population - 2014',
# ...

# %% [markdown]
# **Creating a new df based on total injured persons**

# %%
# Use the melt function to unpivot the DataFrame
melted_df = pd.melt(injured, id_vars=['States/UTs'],
                    value_vars=['State/UT-wise Total Number of Persons Injured in Road Accidents during - 2014',
                                'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2015',
                                'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2016',
                                'State/UT-wise Total Number of Persons Injured in Road Accidents during - 2017',
                               ],
                    var_name='Year', value_name='Total_Persons_Injured')

# Extract the year from the 'Year' column
melted_df['Year'] = melted_df['Year'].str.extract(r'(\d{4})').astype(int)

# Display the result
print(melted_df[['States/UTs', 'Total_Persons_Injured', 'Year']].head())
# Out:
#           States/UTs  Total_Persons_Injured  Year
# 0     Andhra Pradesh                  29931  2014
# 1  Arunachal Pradesh                    308  2014
# 2              Assam                   6499  2014
# 3              Bihar                   6640  2014
# 4       Chhattisgarh                  13157  2014

# %%
melted_df['States/UTs'].nunique()
# Out:
# 37

# %%
melted_df
# Out:
#             States/UTs  Year  Total_Persons_Injured
# 0       Andhra Pradesh  2014                  29931
# 1    Arunachal Pradesh  2014                    308
# 2                Assam  2014                   6499
# 3                Bihar  2014                   6640
# 4         Chhattisgarh  2014                  13157
# ..                 ...   ...                    ...
# 143        Daman & Diu  2017                     70
# 144              Delhi  2017                   6604
# 145        Lakshadweep  2017                      1
# 146         Puducherry  2017                   1741
# 147              Total  2017                 470975
#
# [148 rows x 3 columns]

# %% [markdown]
# **Creating a new df based on Estimated total population**

# %%
# Use the melt function to unpivot the DataFrame
melted_df1 = pd.melt(injured, id_vars=['States/UTs'],
                    value_vars=['Estimated Total Population - 2014',
       'Estimated Total Population - 2015',
       'Estimated Total Population - 2016',
       'Estimated Total Population - 2017'],
                    var_name='Year', value_name='Total_population')

# Extract the year from the 'Year' column
melted_df1['Year'] = melted_df1['Year'].str.extract(r'(\d{4})').astype(int)

# Display the result
print(melted_df1[['States/UTs', 'Total_population', 'Year']].head())
# Out:
#           States/UTs  Total_population  Year
# 0     Andhra Pradesh      8.700872e+07  2014
# 1  Arunachal Pradesh      1.283333e+06  2014
# 2              Assam      3.170244e+07  2014
# 3              Bihar      1.021538e+08  2014
# 4       Chhattisgarh      2.525336e+07  2014

# %%
melted_df1.shape
# Out:
# (148, 3)

# %% [markdown]
# **combining the total injured and estimated total population**

# %%
# Merge the two DataFrames based on 'States/UTs' and 'Year'
combined_df = pd.merge(melted_df, melted_df1, on=['States/UTs', 'Year'])

# Display the result
print(combined_df[['States/UTs', 'Total_Persons_Injured', 'Total_population', 'Year']])
# Out:
#             States/UTs  Total_Persons_Injured  Total_population  Year
# 0       Andhra Pradesh                  29931      8.700872e+07  2014
# 1    Arunachal Pradesh                    308      1.283333e+06  2014
# 2                Assam                   6499      3.170244e+07  2014
# 3                Bihar                   6640      1.021538e+08  2014
# 4         Chhattisgarh                  13157      2.525336e+07  2014
# ..                 ...                    ...               ...   ...
# 143        Daman & Diu                     70      3.448276e+05  2017
# 144              Delhi                   6604      2.186755e+07  2017
# 145        Lakshadweep                      1      8.333333e+04  2017
# 146         Puducherry                   1741      1.732338e+06  2017
# 147              Total                 470975      1.283311e+09  2017
#
# [148 rows x 4 columns]

# %%
combined_df.isnull().sum()
# Out:
# States/UTs               0
# Year                     0
# Total_Persons_Injured    0
# Total_population         5
# dtype: int64

# %%
melted_df.isnull().sum()
# Out:
# States/UTs               0
# Year                     0
# Total_Persons_Injured    0
# dtype: int64

# %%
melted_df1.isnull().sum()
# Out:
# States/UTs          0
# Year                0
# Total_population    5
# dtype: int64

# %% [markdown]
# # killed_data

# %%
killed_data.head()
# Out:
#           States/UTs  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014  \
# 0                                               7908
# 1                                                119
# 2                                               2522
# 3                                               4913
# 4                                               4022
#
#    State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015  \
# 0                                               8297
# 1                                                127
# 2                                               2397
# 3                                               5421
# 4                                               4082
#
#    State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016  \
# ...

# %%
killed_data.tail()
# Out:
#      States/UTs  \
# 32  Daman & Diu
# 33        Delhi
# 34  Lakshadweep
# 35   Puducherry
# 36        Total
#
#     State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014  \
# 32                                                 15
# 33                                               1671
# 34                                                  0
# 35                                                151
# 36                                             139671
#
#     State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015  \
# 32                                                 42
# 33                                               1622
# 34                                                  0
# 35                                                235
# 36                                             146133
#
#     State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016  \
# 32                                                 38
# ...

# %%
killed_data.columns
# Out:
# Index(['States/UTs',
#        'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014',
#        'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015',
#        'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016',
#        'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2017',
#        'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2014',
#        'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2015',
#        'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2016',
#        'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2017',
#        'Total Number of Persons Killed in Road Accidents Per Lakh Population - 2014',
#        'Total Number of Persons Killed in Road Accidents Per Lakh Population - 2015',
# ...

# %%
killed_data.describe()
# Out:
#        State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014  \
# count                                          37.000000
# mean                                         7549.783784
# std                                         22784.381050
# min                                             0.000000
# 25%                                           141.000000
# 50%                                          2522.000000
# 75%                                          6906.000000
# max                                        139671.000000
#
#        State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015  \
# count                                          37.000000
# mean                                         7899.081081
# std                                         23843.582649
# min                                             0.000000
# 25%                                           139.000000
# ...

# %%
killed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 19 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   States/UTs                                                                      37 non-null     object
#  1   State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014    37 non-null     int64
#  2   State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015    37 non-null     int64
#  3   State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016    37 non-null     int64
#  4   State/UT-wise Total Number of Persons Killed in Road Accidents during - 2017    37 non-null     int64
#  5   Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2014  37 non-null     float64
# ...

# %%
killed_data.isnull().sum().sort_values(ascending=True)
# Out:
# States/UTs                                                                        0
# Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2014    0
# Total Number of Persons Killed in Road Accidents per 10,000 Vehicles - 2016       0
# Total Number of Persons Killed in Road Accidents per 10,000 Vehicles - 2015       0
# Total Number of Persons Killed in Road Accidents per 10,000 Vehicles - 2014       0
# Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2015    0
# Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2017    0
# Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2016    0
# Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2015    0
# Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2014    0
# State/UT-wise Total Number of Persons Killed in Road Accidents during - 2017      0
# ...

# %%
killed_data.drop_duplicates()
# Out:
#                    States/UTs  \
# 0              Andhra Pradesh
# 1           Arunachal Pradesh
# 2                       Assam
# 3                       Bihar
# 4                Chhattisgarh
# 5                         Goa
# 6                     Gujarat
# 7                     Haryana
# 8            Himachal Pradesh
# 9             Jammu & Kashmir
# 10                  Jharkhand
# 11                  Karnataka
# 12                     Kerala
# 13             Madhya Pradesh
# 14                Maharashtra
# 15                    Manipur
# 16                  Meghalaya
# 17                    Mizoram
# 18                   Nagaland
# 19                     Odisha
# 20                     Punjab
# 21                  Rajasthan
# 22                     Sikkim
# 23                 Tamil Nadu
# 24                  Telangana
# 25                    Tripura
# 26                Uttarakhand
# 27              Uttar Pradesh
# 28                West Bengal
# 29  Andaman & Nicobar Islands
# ...

# %%
killed_data.shape
# Out:
# (37, 19)

# %%
killed_data = killed_data.drop(columns = ['Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2014',
       'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2015',
       'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2016',
       'Share of States/UTs in Total Number of Persons Killed in Road Accidents - 2017',
      ])

# %%
killed_data.shape
# Out:
# (37, 15)

# %%
# Use the melt function to unpivot the DataFrame
melted_df2 = pd.melt(killed_data, id_vars=['States/UTs'],
                    value_vars=['State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014',
                                'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015',
                                'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016',
                                'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2017',
                               ],
                    var_name='Year', value_name='Total_Persons_killed')

# Extract the year from the 'Year' column
melted_df2['Year'] = melted_df2['Year'].str.extract(r'(\d{4})').astype(int)

# Display the result
print(melted_df2[['States/UTs', 'Total_Persons_killed', 'Year']].head())
# Out:
#           States/UTs  Total_Persons_killed  Year
# 0     Andhra Pradesh                  7908  2014
# 1  Arunachal Pradesh                   119  2014
# 2              Assam                  2522  2014
# 3              Bihar                  4913  2014
# 4       Chhattisgarh                  4022  2014

# %%
melted_df2.isnull().sum()
# Out:
# States/UTs              0
# Year                    0
# Total_Persons_killed    0
# dtype: int64

# %%
# Columns for total number of persons killed and corresponding rates
death_columns = [
    'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014',
       'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015',
       'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016',
       'State/UT-wise Total Number of Persons Killed in Road Accidents during - 2017'
]
 
population_columns = ['Total Number of Persons Killed in Road Accidents Per Lakh Population - 2014',
       'Total Number of Persons Killed in Road Accidents Per Lakh Population - 2015',
       'Total Number of Persons Killed in Road Accidents Per Lakh Population - 2016',
       'Total Number of Persons Killed in Road Accidents Per Lakh Population - 2017'
   
]
 
# Calculate estimated total population for each year
for i, death_column in enumerate(death_columns):
    population_column = population_columns[i]
    estimated_population_column = f'Estimated Total Population - {death_column[-4:]}'
    killed_data[estimated_population_column] = (
        killed_data[death_column] /killed_data[population_column] * 100000
    )
 
# Drop the original estimated total population columns
killed_data.drop(columns=population_columns, inplace=True)
 
# Display the updated DataFrame
killed_data.head()
# Out:
#           States/UTs  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    State/UT-wise Total Number of Persons Killed in Road Accidents during - 2014  \
# 0                                               7908
# 1                                                119
# 2                                               2522
# 3                                               4913
# 4                                               4022
#
#    State/UT-wise Total Number of Persons Killed in Road Accidents during - 2015  \
# 0                                               8297
# 1                                                127
# 2                                               2397
# 3                                               5421
# 4                                               4082
#
#    State/UT-wise Total Number of Persons Killed in Road Accidents during - 2016  \
# ...

# %%
# Use the melt function to unpivot the DataFrame
melted_df3 = pd.melt(killed_data, id_vars=['States/UTs'],
                    value_vars=['Estimated Total Population - 2014',
       'Estimated Total Population - 2015',
       'Estimated Total Population - 2016',
       'Estimated Total Population - 2017'],
                    var_name='Year', value_name='Total_population_killed')

# Extract the year from the 'Year' column
melted_df3['Year'] = melted_df3['Year'].str.extract(r'(\d{4})').astype(int)

# Display the result
print(melted_df3[['States/UTs', 'Total_population_killed', 'Year']].head())
# Out:
#           States/UTs  Total_population_killed  Year
# 0     Andhra Pradesh             8.690110e+07  2014
# 1  Arunachal Pradesh             1.279570e+06  2014
# 2              Assam             3.152500e+07  2014
# 3              Bihar             1.023542e+08  2014
# 4       Chhattisgarh             2.529560e+07  2014

# %%
melted_df3.isnull().sum()
# Out:
# States/UTs                 0
# Year                       0
# Total_population_killed    7
# dtype: int64

# %%
# Merge the two DataFrames based on 'States/UTs' and 'Year'
killed_dataset = pd.merge(melted_df2, melted_df3, on=['States/UTs', 'Year'])

# Display the result
print(killed_dataset[['States/UTs', 'Total_Persons_killed', 'Total_population_killed', 'Year']])
# Out:
#             States/UTs  Total_Persons_killed  Total_population_killed  Year
# 0       Andhra Pradesh                  7908             8.690110e+07  2014
# 1    Arunachal Pradesh                   119             1.279570e+06  2014
# 2                Assam                  2522             3.152500e+07  2014
# 3                Bihar                  4913             1.023542e+08  2014
# 4         Chhattisgarh                  4022             2.529560e+07  2014
# ..                 ...                   ...                      ...   ...
# 143        Daman & Diu                    36             3.428571e+05  2017
# 144              Delhi                  1584             2.200000e+07  2017
# 145        Lakshadweep                     0                      NaN  2017
# 146         Puducherry                   233             1.738806e+06  2017
# 147              Total                147913             1.286200e+09  2017
#
# [148 rows x 4 columns]

# %%
killed_dataset['States/UTs'].nunique()
# Out:
# 37

# %%
# Merge the two DataFrames based on 'States/UTs' and 'Year'
injured_killed= pd.merge(combined_df,killed_dataset, on=['States/UTs', 'Year'])

# Display the result
print(injured_killed[['States/UTs', 'Total_Persons_Injured', 'Total_population','Total_Persons_killed', 'Year']])
# Out:
#             States/UTs  Total_Persons_Injured  Total_population  \
# 0       Andhra Pradesh                  29931      8.700872e+07
# 1    Arunachal Pradesh                    308      1.283333e+06
# 2                Assam                   6499      3.170244e+07
# 3                Bihar                   6640      1.021538e+08
# 4         Chhattisgarh                  13157      2.525336e+07
# ..                 ...                    ...               ...
# 143        Daman & Diu                     70      3.448276e+05
# 144              Delhi                   6604      2.186755e+07
# 145        Lakshadweep                      1      8.333333e+04
# 146         Puducherry                   1741      1.732338e+06
# 147              Total                 470975      1.283311e+09
#
#      Total_Persons_killed  Year
# 0                    7908  2014
# 1                     119  2014
# 2                    2522  2014
# 3                    4913  2014
# ...

# %%
injured_killed.head()
# Out:
#           States/UTs  Year  Total_Persons_Injured  Total_population  \
# 0     Andhra Pradesh  2014                  29931      8.700872e+07
# 1  Arunachal Pradesh  2014                    308      1.283333e+06
# 2              Assam  2014                   6499      3.170244e+07
# 3              Bihar  2014                   6640      1.021538e+08
# 4       Chhattisgarh  2014                  13157      2.525336e+07
#
#    Total_Persons_killed  Total_population_killed
# 0                  7908             8.690110e+07
# 1                   119             1.279570e+06
# 2                  2522             3.152500e+07
# 3                  4913             1.023542e+08
# 4                  4022             2.529560e+07

# %% [markdown]
# # Weather dataframe**

# %%
weather.head()
# Out:
#   S. No.          State/ UT  Fine - Total Acc. - 2014  \
# 0      1     Andhra Pradesh                   14591.0
# 1      2  Arunachal Pradesh                      71.0
# 2      3              Assam                    3575.0
# 3      4              Bihar                    2343.0
# 4      5       Chhattisgarh                    5000.0
#
#    Fine - Persons Killed - 2014  Fine - Persons Injured - 2014  \
# 0                          4586                        17065.0
# 1                            30                          110.0
# 2                          1318                         3216.0
# 3                          1218                         1626.0
# 4                          1354                         4584.0
#
#    Mist/fog - Total Acc. - 2014  Mist/fog - Persons Killed - 2014  \
# 0                         724.0                               219
# 1                          14.0                                10
# ...

# %%
weather.shape
# Out:
# (37, 65)

# %%
weather.tail()
# Out:
#    S. No.    State/ UT  Fine - Total Acc. - 2014  \
# 32     33  Daman & Diu                      38.0
# 33     34        Delhi                       NaN
# 34     35  Lakshadweep                       0.0
# 35     36   Puducherry                     453.0
# 36  Total        Total                  310121.0
#
#     Fine - Persons Killed - 2014  Fine - Persons Injured - 2014  \
# 32                            14                           49.0
# 33                          1656                            NaN
# 34                             0                            0.0
# 35                            68                          528.0
# 36                         83727                       312657.0
#
#     Mist/fog - Total Acc. - 2014  Mist/fog - Persons Killed - 2014  \
# 32                           0.0                                 0
# 33                           NaN                                11
# 34                           0.0                                 0
# ...

# %%
weather.columns
# Out:
# Index(['S. No.', 'State/ UT', 'Fine - Total Acc. - 2014',
#        'Fine - Persons Killed - 2014', 'Fine - Persons Injured - 2014',
#        'Mist/fog - Total Acc. - 2014', 'Mist/fog - Persons Killed - 2014',
#        'Mist/fog - Persons Injured - 2014', 'Cloudy - Total Acc. - 2014',
#        'Cloudy - Persons Killed - 2014', 'Cloudy - Persons Injured - 2014',
#        'Light rain - Total Acc. - 2014', 'Light rain - Persons Killed - 2014',
#        'Light rain - Persons Injured - 2014', 'Heavy rain - Total Acc. - 2014',
#        'Heavy rain - Persons Killed - 2014',
#        'Heavy rain - Persons Injured - 2014',
#        'Flooding of slipways/rivulers - Total Acc. - 2014',
#        'Flooding of slipways/rivulers - Persons Killed - 2014',
#        'Flooding of slipways/rivulers - Persons Injured - 2014',
#        'Hail/sleet - Total Acc. - 2014', 'Hail/sleet - Persons Killed - 2014',
#        'Hail/sleet - Persons Injured - 2014', 'snow - Total Acc. - 2014',
# ...

# %%
weather.shape
# Out:
# (37, 65)

# %%
melted_df4 = pd.melt(weather, id_vars=['S. No.', 'State/ UT'],
                    value_vars=[
                'Fine - Persons Killed - 2014',
                'Mist/fog - Persons Killed - 2014',
                'Cloudy - Persons Killed - 2014',
                'Light rain - Persons Killed - 2014',
                'Heavy rain - Persons Killed - 2014',
                'Flooding of slipways/rivulers - Persons Killed - 2014',
                'Hail/sleet - Persons Killed - 2014',
                'snow - Persons Killed - 2014',
                'Strong wind - Persons Killed - 2014',
                'Dust storm - Persons Killed - 2014',
                'Very hot - Persons Killed - 2014',
                'Very cold - Persons Killed - 2014',
                'Other extraordinary weather condition - Persons Killed - 2014',
                'Fine/Clear - Persons Killed - 2016',
                'Mist/ Foggy - Persons Killed - 2016',
                'Cloudy - Persons Killed - 2016',
                'Rainy - Persons Killed - 2016',
                'Snowfall - Persons Killed - 2016',
                'Hail/Sleet - Persons Killed - 2016',
                'Dust Storm - Persons Killed - 2016',
                'Others - Persons Killed - 2016'],
                    var_name='weather_year', value_name='Total_killed_weather')

# Extract the year from the 'Year' column
melted_df4['Year'] = melted_df4['weather_year'].str.split('-').str.get(-1).astype(int)
#Extract the weather from the column names
melted_df4['weather_condition']=melted_df4['weather_year'].str.split('-').str.get(0)

#melted4=melted_df4[melted_df4['Total_killed_weather'].notna()]
# Display the result
melted_df4.head()
# Out:
#   S. No.          State/ UT                  weather_year  \
# 0      1     Andhra Pradesh  Fine - Persons Killed - 2014
# 1      2  Arunachal Pradesh  Fine - Persons Killed - 2014
# 2      3              Assam  Fine - Persons Killed - 2014
# 3      4              Bihar  Fine - Persons Killed - 2014
# 4      5       Chhattisgarh  Fine - Persons Killed - 2014
#
#    Total_killed_weather  Year weather_condition
# 0                4586.0  2014             Fine
# 1                  30.0  2014             Fine
# 2                1318.0  2014             Fine
# 3                1218.0  2014             Fine
# 4                1354.0  2014             Fine

# %%
melted_df4= pd.melt(weather, id_vars=['S. No.','State/ UT'], value_vars=[
                'Fine - Persons Killed - 2014',
 
                'Mist/fog - Persons Killed - 2014',
 
                'Cloudy - Persons Killed - 2014',
 
                'Light rain - Persons Killed - 2014',
 
                'Heavy rain - Persons Killed - 2014',
 
                'Flooding of slipways/rivulers - Persons Killed - 2014',
 
                'Hail/sleet - Persons Killed - 2014',
 
                'snow - Persons Killed - 2014',
 
                'Strong wind - Persons Killed - 2014',
 
                'Dust storm - Persons Killed - 2014',
 
                'Very hot - Persons Killed - 2014',
 
                'Very cold - Persons Killed - 2014',
                'Other extraordinary weather condition - Persons Killed - 2014',
 
                'Fine/Clear - Persons Killed - 2016',
 
                'Mist/ Foggy - Persons Killed - 2016',
 
                'Cloudy - Persons Killed - 2016',
 
                'Rainy - Persons Killed - 2016',
 
                'Snowfall - Persons Killed - 2016',
 
                'Hail/Sleet - Persons Killed - 2016',
 
                'Dust Storm - Persons Killed - 2016',
 
                'Others - Persons Killed - 2016'],
                    var_name='weather_year', value_name='Total_killed_Accidents_weather')
melted_df4['Year'] = melted_df4['weather_year'].str.split(' - ').str.get(-1).astype(int)
melted_df4['weather_condition'] = melted_df4['weather_year'].str.split(' - ').str.get(0)
#melted4=melted_df4[melted_df4['Total_killed_Accidents_weather'].notna()]
melted_df4.head()
# Out:
#   S. No.          State/ UT                  weather_year  \
# 0      1     Andhra Pradesh  Fine - Persons Killed - 2014
# 1      2  Arunachal Pradesh  Fine - Persons Killed - 2014
# 2      3              Assam  Fine - Persons Killed - 2014
# 3      4              Bihar  Fine - Persons Killed - 2014
# 4      5       Chhattisgarh  Fine - Persons Killed - 2014
#
#    Total_killed_Accidents_weather  Year weather_condition
# 0                          4586.0  2014              Fine
# 1                            30.0  2014              Fine
# 2                          1318.0  2014              Fine
# 3                          1218.0  2014              Fine
# 4                          1354.0  2014              Fine

# %%
melted_df4.shape
# Out:
# (777, 6)

# %%
# Use the melt function to unpivot the DataFrame
melted_df5= pd.melt(weather, id_vars=['S. No.','State/ UT'], value_vars=['Fine - Persons Injured - 2014',
       'Mist/fog - Persons Injured - 2014',
      'Cloudy - Persons Injured - 2014',
       'Light rain - Persons Injured - 2014',
       'Heavy rain - Persons Injured - 2014',
       'Flooding of slipways/rivulers - Persons Injured - 2014',
       'Hail/sleet - Persons Injured - 2014','snow - Persons Injured - 2014',
       'Strong wind - Persons Injured - 2014',
       'Dust storm - Persons Injured - 2014', 
       'Very hot - Persons Injured - 2014',
       'Very cold - Persons Injured - 2014',
       'Other extraordinary weather condition - Persons Injured - 2014',
       'Fine/Clear - Persons Injured - 2016',
       'Mist/ Foggy - Persons Injured - 2016',
       'Cloudy - Persons Injured - 2016', 
      'Rainy - Persons Injured - 2016',
       'Snowfall - Persons Injured - 2016',
       'Hail/Sleet - Persons Injured - 2016',
       'Dust Storm - Persons Injured - 2016',
       'Others - Persons Injured - 2016'],
                    var_name='weather_year', value_name='Total_Persons_Injured_weather')
melted_df5['Year'] = melted_df5['weather_year'].str.split(' - ').str.get(-1).astype(int)

melted_df5['weather_condition'] = melted_df5['weather_year'].str.split(' - ').str.get(0)
#melted5=melted_df5[melted_df5['Total_Persons_Injured_weather'].notna()]
 
# Display the result
melted_df5.head()
# Out:
#   S. No.          State/ UT                   weather_year  \
# 0      1     Andhra Pradesh  Fine - Persons Injured - 2014
# 1      2  Arunachal Pradesh  Fine - Persons Injured - 2014
# 2      3              Assam  Fine - Persons Injured - 2014
# 3      4              Bihar  Fine - Persons Injured - 2014
# 4      5       Chhattisgarh  Fine - Persons Injured - 2014
#
#    Total_Persons_Injured_weather  Year weather_condition
# 0                        17065.0  2014              Fine
# 1                          110.0  2014              Fine
# 2                         3216.0  2014              Fine
# 3                         1626.0  2014              Fine
# 4                         4584.0  2014              Fine

# %%
melted_df6= pd.melt(weather, id_vars=['S. No.','State/ UT'], value_vars=['Fine - Total Acc. - 2014',
       'Mist/fog - Total Acc. - 2014',
      'Cloudy - Total Acc. - 2014',
       'Light rain - Total Acc. - 2014',
       'Heavy rain - Total Acc. - 2014',
       'Flooding of slipways/rivulers - Total Acc. - 2014',
       'Hail/sleet - Total Acc. - 2014','snow - Total Acc. - 2014',
       'Strong wind - Total Acc. - 2014',
       'Dust storm - Total Acc. - 2014', 
       'Very hot - Total Acc. - 2014',
       'Very cold - Total Acc. - 2014',
       'Other extraordinary weather condition - Total Acc. - 2014',
       'Fine/Clear - Total Accidents - 2016',
       'Mist/ Foggy - Total Accidents - 2016',
       'Cloudy - Total Accidents - 2016', 
      'Rainy - Total Accidents - 2016',
       'Snowfall - Total Accidents - 2016',
       'Hail/Sleet - Total Accidents - 2016',
       'Dust Storm - Total Accidents - 2016',
       'Others - Total Accidents - 2016'],
                    var_name='weather_year', value_name='Total_Total_Accidents_weather')
melted_df6['Year'] = melted_df6['weather_year'].str.split(' - ').str.get(-1).astype(int)
melted_df6['weather_condition'] = melted_df6['weather_year'].str.split(' - ').str.get(0)
#melted6=melted_df6[melted_df6['Total_Total_Accidents_weather'].notna()]
 
# Display the result
melted_df6.head()
# Out:
#   S. No.          State/ UT              weather_year  \
# 0      1     Andhra Pradesh  Fine - Total Acc. - 2014
# 1      2  Arunachal Pradesh  Fine - Total Acc. - 2014
# 2      3              Assam  Fine - Total Acc. - 2014
# 3      4              Bihar  Fine - Total Acc. - 2014
# 4      5       Chhattisgarh  Fine - Total Acc. - 2014
#
#    Total_Total_Accidents_weather  Year weather_condition
# 0                        14591.0  2014              Fine
# 1                           71.0  2014              Fine
# 2                         3575.0  2014              Fine
# 3                         2343.0  2014              Fine
# 4                         5000.0  2014              Fine

# %% [markdown]
# combine=pd.merge(melted4,melted5,on=['State/ UT','Year','

# %%
combine=pd.merge(melted_df4,melted_df5,on=['State/ UT','Year','weather_condition'])
weather_combined=pd.merge(combine,melted_df6,on=['State/ UT','Year','weather_condition'])
weather_combined.head()  
#Year State/ UT weather_condition Year State/ UT weather_condition
# Out:
#   S. No._x          State/ UT                weather_year_x  \
# 0        1     Andhra Pradesh  Fine - Persons Killed - 2014
# 1        2  Arunachal Pradesh  Fine - Persons Killed - 2014
# 2        3              Assam  Fine - Persons Killed - 2014
# 3        4              Bihar  Fine - Persons Killed - 2014
# 4        5       Chhattisgarh  Fine - Persons Killed - 2014
#
#    Total_killed_Accidents_weather  Year weather_condition S. No._y  \
# 0                          4586.0  2014              Fine        1
# 1                            30.0  2014              Fine        2
# 2                          1318.0  2014              Fine        3
# 3                          1218.0  2014              Fine        4
# 4                          1354.0  2014              Fine        5
#
#                   weather_year_y  Total_Persons_Injured_weather S. No.  \
# 0  Fine - Persons Injured - 2014                        17065.0      1
# ...

# %%
weather_combined.shape
# Out:
# (777, 12)

# %%
weather_combined.drop(['S. No._x','S. No._y','weather_year_x','weather_year_y','weather_year','S. No.'],axis=1,inplace=True)

# %%
weather_combined.head()
# Out:
#            State/ UT  Total_killed_Accidents_weather  Year weather_condition  \
# 0     Andhra Pradesh                          4586.0  2014              Fine
# 1  Arunachal Pradesh                            30.0  2014              Fine
# 2              Assam                          1318.0  2014              Fine
# 3              Bihar                          1218.0  2014              Fine
# 4       Chhattisgarh                          1354.0  2014              Fine
#
#    Total_Persons_Injured_weather  Total_Total_Accidents_weather
# 0                        17065.0                        14591.0
# 1                          110.0                           71.0
# 2                         3216.0                         3575.0
# 3                         1626.0                         2343.0
# 4                         4584.0                         5000.0

# %% [markdown]
# # Combing the 3 dataFrames

# %%
weather_combined.rename(columns={'State/ UT':'States/UTs'},inplace=True)

# %%
weather_combined.columns
# Out:
# Index(['States/UTs', 'Total_killed_Accidents_weather', 'Year',
#        'weather_condition', 'Total_Persons_Injured_weather',
#        'Total_Total_Accidents_weather'],
#       dtype='object')

# %%
injured_killed.columns
# Out:
# Index(['States/UTs', 'Year', 'Total_Persons_Injured', 'Total_population',
#        'Total_Persons_killed', 'Total_population_killed'],
#       dtype='object')

# %%
state_mapping = {
    'A & N Islands':'Andaman & Nicobar Islands',
    'D & N Haveli':'Dadra & Nagar Haveli',
    'Orissa':'Odisha'
}
 
# Replace misspelled state names with correct names
weather_combined['States/UTs'] = weather_combined['States/UTs'].replace(state_mapping)

# %%
three_datasets=pd.merge(weather_combined,injured_killed,on=['States/UTs','Year'])
three_datasets.head()
three_datasets.drop(['Total_population_killed'],axis=1,inplace=True)

# %%
three_datasets.shape
# Out:
# (777, 9)

# %%
three_datasets.head()
# Out:
#        States/UTs  Total_killed_Accidents_weather  Year weather_condition  \
# 0  Andhra Pradesh                          4586.0  2014              Fine
# 1  Andhra Pradesh                           219.0  2014          Mist/fog
# 2  Andhra Pradesh                           188.0  2014            Cloudy
# 3  Andhra Pradesh                           368.0  2014        Light rain
# 4  Andhra Pradesh                           231.0  2014        Heavy rain
#
#    Total_Persons_Injured_weather  Total_Total_Accidents_weather  \
# 0                        17065.0                        14591.0
# 1                          925.0                          724.0
# 2                          916.0                          647.0
# 3                         1440.0                         1104.0
# 4                          856.0                          695.0
#
#    Total_Persons_Injured  Total_population  Total_Persons_killed
# 0                  29931      8.700872e+07                  7908
# ...

# %% [markdown]
# # Road DataFrame

# %%
road_type.head()
# Out:
#   S. No.          State/ UT  Surfaced Roads-Accident - 2014  \
# 0      1     Andhra Pradesh                         13846.0
# 1      2  Arunachal Pradesh                            81.0
# 2      3              Assam                          4948.0
# 3      4              Bihar                          5990.0
# 4      5       Chhattisgarh                          7248.0
#
#    Surfaced Roads- Killed - 2014  Surfaced Roads-Injured - 2014  \
# 0                           4333                        17323.0
# 1                             43                          111.0
# 2                           1631                         5043.0
# 3                           3184                         3732.0
# 4                           2111                         7170.0
#
#    Metalled Roads-Accident - 2014  Metalled Roads- Killed - 2014  \
# 0                          5211.0                           2392
# 1                            73.0                             37
# ...

# %%
road_type.columns
# Out:
# Index(['S. No.', 'State/ UT', 'Surfaced Roads-Accident - 2014',
#        'Surfaced Roads- Killed - 2014', 'Surfaced Roads-Injured - 2014',
#        'Metalled Roads-Accident - 2014', 'Metalled Roads- Killed - 2014',
#        'Metalled Roads-Injured - 2014', 'Kutcha Roads-Accident - 2014',
#        'Kutcha Roads- Killed - 2014', 'Kutcha Roads-Injured - 2014',
#        'Dry road-Accident - 2014', 'Dry road- Killed - 2014',
#        'Dry road-Injured - 2014', 'Wet road-Accident - 2014',
#        'Wet road- Killed - 2014', 'Wet road-Injured - 2014',
#        'Good surface-Accident - 2014', 'Good surface- Killed - 2014',
#        'Good surface-Injured - 2014', 'Loose Surface-Accident - 2014',
#        'Loose Surface- Killed - 2014', 'Loose Surface-Injured - 2014',
#        'Rutted/Pot holes-Accident - 2014', 'Rutted/Pot holes- Killed - 2014',
#        'Rutted/Pot holes-Injured - 2014',
#        'Road under repair/construction-Accident - 2014',
# ...

# %%
road_type.shape
# Out:
# (37, 98)

# %%
road_killed =['Surfaced Roads- Killed - 2014',
       'Metalled Roads- Killed - 2014',
       'Kutcha Roads- Killed - 2014',
       'Dry road- Killed - 2014',
       'Wet road- Killed - 2014',
       'Good surface- Killed - 2014',
       'Loose Surface- Killed - 2014',
       'Rutted/Pot holes- Killed - 2014',
       'Road under repair/construction- Killed - 2014',
       'Corrugated/Wavy road- Killed - 2014',
       'Slippery surface- Killed - 2014',
       'Snowy- Killed - 2014',
       'Muddy- Killed - 2014',
       'Oily- Killed - 2014',
       'Speed breaker- Killed - 2014',
       'Others- Killed - 2014',
       'Straight Road-Killed - 2014',
       'Slight Curve-Killed - 2014',
       'Sharp Curve-Killed - 2014',
       'Flat Road-Killed - 2014',
       'Gentle Incline-Killed - 2014',
       'Steep Incline-Killed - 2014', 
       'Hump-Killed - 2014',
       'Dip-Killed - 2014',
       'Pucca road (Normal Road) - Persons Killed - 2016',
       'Kutcha road (Normal Road) - Persons Killed - 2016',
       'Pot Holes - Persons Killed - 2016',
       'Speed Breakers - Persons Killed - 2016',
       'Sharp Curve - Persons Killed - 2016',
       'Steep Gradient - Persons Killed - 2016',
       'Earthern Shoulder Edge Drop - Persons Killed - 2016',
       'Others - Persons Killed - 2016']
len(road_killed)
# Out:
# 32

# %%
road_injured=['Surfaced Roads-Injured - 2014',
              'Metalled Roads-Injured - 2014','Kutcha Roads-Injured - 2014',
              'Dry road-Injured - 2014',
              'Wet road-Injured - 2014',
              'Good surface-Injured - 2014',
              'Loose Surface-Injured - 2014',
              'Rutted/Pot holes-Injured - 2014',
              'Road under repair/construction-Injured - 2014',
              'Corrugated/Wavy road-Injured - 2014',
              'Slippery surface-Injured - 2014',
              'Snowy-Injured - 2014',
              'Muddy-Injured - 2014', 
              'Oily-Injured - 2014',
              'Speed breaker-Injured - 2014',
              'Others-Injured - 2014',
              'Straight Road-Injured - 2014',
              'Slight Curve-Injured - 2014',
              'Sharp Curve-Injured - 2014',
              'Flat Road-Injured - 2014',
              'Gentle Incline-Injured - 2014', 
              'Steep Incline-Injured - 2014',
              'Hump-Injured - 2014',
              'Dip-Injured - 2014',
              'Pucca road (Normal Road) - Persons Injured - 2016',
              'Kutcha road (Normal Road) - Persons Injured - 2016',
              'Pot Holes - Persons Injured - 2016',
              'Speed Breakers - Persons Injured - 2016',
              'Sharp Curve - Persons Injured - 2016',
              'Steep Gradient - Persons Injured - 2016',
              'Earthern Shoulder Edge Drop - Persons Injured - 2016',
              'Others - Persons Injured - 2016']

# %%
road_accidents=['Surfaced Roads-Accident - 2014', 
                'Metalled Roads-Accident - 2014',
                'Kutcha Roads-Accident - 2014',
                'Dry road-Accident - 2014',
                'Wet road-Accident - 2014',
                'Good surface-Accident - 2014', 
                'Loose Surface-Accident - 2014',
                'Rutted/Pot holes-Accident - 2014',
                'Road under repair/construction-Accident - 2014',
                'Corrugated/Wavy road-Accident - 2014',
                'Slippery surface-Accident - 2014',
                'Snowy-Accident - 2014',
                'Muddy-Accident - 2014',
                'Oily-Accident - 2014','Speed breaker-Accident - 2014','Others-Accident - 2014','Straight Road-Accidents - 2014','Slight Curve-Accidents - 2014','Sharp Curve-Accidents - 2014','Flat Road-Accidents - 2014','Gentle Incline-Accidents - 2014','Steep Incline-Accidents - 2014','Hump-Accidents - 2014','Dip-Accidents - 2014','Pucca road (Normal Road) - Number of Accidents - 2016','Kutcha road (Normal Road) - Number of Accidents - 2016','Pot Holes - Number of Accidents - 2016','Speed Breakers - Number of Accidents - 2016','Sharp Curve - Number of Accidents - 2016','Steep Gradient - Number of Accidents - 2016','Earthern Shoulder Edge Drop - Number of Accidents - 2016','Others - Number of Accidents - 2016',]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
injured_melt= pd.melt(road_type, id_vars=['State/ UT'], value_vars=road_injured,var_name='road_type_year', value_name='Total_injured_roadtype')
injured_melt['Year'] = injured_melt['road_type_year'].str.split('-').str.get(-1).astype(int)
injured_melt['Road_type'] = injured_melt['road_type_year'].str.split('-').str.get(0)
#result_injured=injured_melt[injured_melt['Total_injured_roadtype'].notna()]
#result_injured.drop(['road_type_year'],axis=1,inplace=True)
injured_melt.head()
# Out:
#            State/ UT                 road_type_year  Total_injured_roadtype  \
# 0     Andhra Pradesh  Surfaced Roads-Injured - 2014                 17323.0
# 1  Arunachal Pradesh  Surfaced Roads-Injured - 2014                   111.0
# 2              Assam  Surfaced Roads-Injured - 2014                  5043.0
# 3              Bihar  Surfaced Roads-Injured - 2014                  3732.0
# 4       Chhattisgarh  Surfaced Roads-Injured - 2014                  7170.0
#
#    Year       Road_type
# 0  2014  Surfaced Roads
# 1  2014  Surfaced Roads
# 2  2014  Surfaced Roads
# 3  2014  Surfaced Roads
# 4  2014  Surfaced Roads

# %%
Killed_melt= pd.melt(road_type, id_vars=['State/ UT'], value_vars=road_killed,var_name='road_type_year', value_name='Total_Killed_roadtype')
Killed_melt['Year'] = Killed_melt['road_type_year'].str.split('-').str.get(-1).astype(int)
Killed_melt['Road_type'] = Killed_melt['road_type_year'].str.split('-').str.get(0)
#result_Killed=Killed_melt[Killed_melt['Total_Killed_roadtype'].notna()]
#result_Killed.drop(['road_type_year'],axis=1,inplace=True)
Killed_melt.shape
# Out:
# (1184, 5)

# %%
Killed_melt.head()
# Out:
#            State/ UT                 road_type_year  Total_Killed_roadtype  \
# 0     Andhra Pradesh  Surfaced Roads- Killed - 2014                   4333
# 1  Arunachal Pradesh  Surfaced Roads- Killed - 2014                     43
# 2              Assam  Surfaced Roads- Killed - 2014                   1631
# 3              Bihar  Surfaced Roads- Killed - 2014                   3184
# 4       Chhattisgarh  Surfaced Roads- Killed - 2014                   2111
#
#    Year       Road_type
# 0  2014  Surfaced Roads
# 1  2014  Surfaced Roads
# 2  2014  Surfaced Roads
# 3  2014  Surfaced Roads
# 4  2014  Surfaced Roads

# %%
Accidents_melt= pd.melt(road_type, id_vars=['State/ UT'], value_vars=road_accidents,var_name='road_type_year', value_name='Total_Accidents_roadtype')
Accidents_melt['Year'] = Accidents_melt['road_type_year'].str.split('-').str.get(-1).astype(int)
Accidents_melt['Road_type'] = Accidents_melt['road_type_year'].str.split('-').str.get(0)
#result_Accidents=Accidents_melt[Accidents_melt['Total_Accidents_roadtype'].notna()]
#result_Accidents.drop(['road_type_year'],axis=1,inplace=True)
Accidents_melt.head()
# Out:
#            State/ UT                  road_type_year  \
# 0     Andhra Pradesh  Surfaced Roads-Accident - 2014
# 1  Arunachal Pradesh  Surfaced Roads-Accident - 2014
# 2              Assam  Surfaced Roads-Accident - 2014
# 3              Bihar  Surfaced Roads-Accident - 2014
# 4       Chhattisgarh  Surfaced Roads-Accident - 2014
#
#    Total_Accidents_roadtype  Year       Road_type
# 0                   13846.0  2014  Surfaced Roads
# 1                      81.0  2014  Surfaced Roads
# 2                    4948.0  2014  Surfaced Roads
# 3                    5990.0  2014  Surfaced Roads
# 4                    7248.0  2014  Surfaced Roads

# %%
combine_two = pd.merge(injured_melt,Killed_melt, on=["State/ UT", 'Year', 'Road_type'])
combine_two.head()
# Out:
#            State/ UT               road_type_year_x  Total_injured_roadtype  \
# 0     Andhra Pradesh  Surfaced Roads-Injured - 2014                 17323.0
# 1  Arunachal Pradesh  Surfaced Roads-Injured - 2014                   111.0
# 2              Assam  Surfaced Roads-Injured - 2014                  5043.0
# 3              Bihar  Surfaced Roads-Injured - 2014                  3732.0
# 4       Chhattisgarh  Surfaced Roads-Injured - 2014                  7170.0
#
#    Year       Road_type               road_type_year_y  Total_Killed_roadtype
# 0  2014  Surfaced Roads  Surfaced Roads- Killed - 2014                   4333
# 1  2014  Surfaced Roads  Surfaced Roads- Killed - 2014                     43
# 2  2014  Surfaced Roads  Surfaced Roads- Killed - 2014                   1631
# 3  2014  Surfaced Roads  Surfaced Roads- Killed - 2014                   3184
# 4  2014  Surfaced Roads  Surfaced Roads- Killed - 2014                   2111

# %%
roadtype_data=pd.merge(combine_two,Accidents_melt, on=["State/ UT", 'Year', 'Road_type'])
roadtype_data.drop(['road_type_year','road_type_year_x','road_type_year_y'],axis=1,inplace=True)

# %%
roadtype_data.rename({'State/ UT':'States/UTs'},axis=1,inplace=True)

# %%
state_mapping = {
    'A & N Islands':'Andaman & Nicobar Islands',
    'D & N Haveli':'Dadra & Nagar Haveli',
    'Orissa':'Odisha'
}
 
# Replace misspelled state names with correct names
roadtype_data['States/UTs'] = roadtype_data['States/UTs'].replace(state_mapping)

# %%
combine_two.nunique()
# Out:
# State/ UT                  37
# road_type_year_x           32
# Total_injured_roadtype    647
# Year                        2
# Road_type                  32
# road_type_year_y           32
# Total_Killed_roadtype     516
# dtype: int64

# %%
combine_two.shape
# Out:
# (1184, 7)

# %%
roadtype_data.shape
# Out:
# (1184, 6)

# %%
roadtype_data.head()
# Out:
#           States/UTs  Total_injured_roadtype  Year       Road_type  \
# 0     Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 1  Arunachal Pradesh                   111.0  2014  Surfaced Roads
# 2              Assam                  5043.0  2014  Surfaced Roads
# 3              Bihar                  3732.0  2014  Surfaced Roads
# 4       Chhattisgarh                  7170.0  2014  Surfaced Roads
#
#    Total_Killed_roadtype  Total_Accidents_roadtype
# 0                   4333                   13846.0
# 1                     43                      81.0
# 2                   1631                    4948.0
# 3                   3184                    5990.0
# 4                   2111                    7248.0

# %%
roadtype_data.rename({'State/ UT':'States/UTs'},axis=1,inplace=True)

# %%
roadtype_data.columns
# Out:
# Index(['States/UTs', 'Total_injured_roadtype', 'Year', 'Road_type',
#        'Total_Killed_roadtype', 'Total_Accidents_roadtype'],
#       dtype='object')

# %%
roadtype_data['States/UTs'].nunique()
# Out:
# 37

# %%
final_data=pd.merge(roadtype_data,three_datasets,on=['States/UTs','Year'])

# %%
final_data.head()
# Out:
#        States/UTs  Total_injured_roadtype  Year       Road_type  \
# 0  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 1  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 2  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 3  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 4  Andhra Pradesh                 17323.0  2014  Surfaced Roads
#
#    Total_Killed_roadtype  Total_Accidents_roadtype  \
# 0                   4333                   13846.0
# 1                   4333                   13846.0
# 2                   4333                   13846.0
# 3                   4333                   13846.0
# 4                   4333                   13846.0
#
#    Total_killed_Accidents_weather weather_condition  \
# 0                          4586.0              Fine
# 1                           219.0          Mist/fog
# 2                           188.0            Cloudy
# 3                           368.0        Light rain
# ...

# %%
final_data.shape
# Out:
# (13912, 13)

# %%
final_data.drop_duplicates()
# Out:
#            States/UTs  Total_injured_roadtype  Year       Road_type  \
# 0      Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 1      Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 2      Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 3      Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 4      Andhra Pradesh                 17323.0  2014  Surfaced Roads
# ...               ...                     ...   ...             ...
# 13907           Total                 65817.0  2016         Others
# 13908           Total                 65817.0  2016         Others
# 13909           Total                 65817.0  2016         Others
# 13910           Total                 65817.0  2016         Others
# 13911           Total                 65817.0  2016         Others
#
#        Total_Killed_roadtype  Total_Accidents_roadtype  \
# 0                       4333                   13846.0
# ...

# %%
final_data.shape
# Out:
# (13912, 13)

# %%
final_data.head()
# Out:
#        States/UTs  Total_injured_roadtype  Year       Road_type  \
# 0  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 1  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 2  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 3  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 4  Andhra Pradesh                 17323.0  2014  Surfaced Roads
#
#    Total_Killed_roadtype  Total_Accidents_roadtype  \
# 0                   4333                   13846.0
# 1                   4333                   13846.0
# 2                   4333                   13846.0
# 3                   4333                   13846.0
# 4                   4333                   13846.0
#
#    Total_killed_Accidents_weather weather_condition  \
# 0                          4586.0              Fine
# 1                           219.0          Mist/fog
# 2                           188.0            Cloudy
# 3                           368.0        Light rain
# ...

# %%
final_data.columns
# Out:
# Index(['States/UTs', 'Total_injured_roadtype', 'Year', 'Road_type',
#        'Total_Killed_roadtype', 'Total_Accidents_roadtype',
#        'Total_killed_Accidents_weather', 'weather_condition',
#        'Total_Persons_Injured_weather', 'Total_Total_Accidents_weather',
#        'Total_Persons_Injured', 'Total_population', 'Total_Persons_killed'],
#       dtype='object')

# %%
final_data.shape
# Out:
# (13912, 13)

# %%
final_data.head()
# Out:
#        States/UTs  Total_injured_roadtype  Year       Road_type  \
# 0  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 1  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 2  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 3  Andhra Pradesh                 17323.0  2014  Surfaced Roads
# 4  Andhra Pradesh                 17323.0  2014  Surfaced Roads
#
#    Total_Killed_roadtype  Total_Accidents_roadtype  \
# 0                   4333                   13846.0
# 1                   4333                   13846.0
# 2                   4333                   13846.0
# 3                   4333                   13846.0
# 4                   4333                   13846.0
#
#    Total_killed_Accidents_weather weather_condition  \
# 0                          4586.0              Fine
# 1                           219.0          Mist/fog
# 2                           188.0            Cloudy
# 3                           368.0        Light rain
# ...

# %%
final_data['States/UTs'].nunique()
# Out:
# 37

# %%
#final_data['Year'] = final_data.to_datetime(final_data['Year'], format='%Y')

# %% [markdown]
# # **Data Analysis**

# %%
import matplotlib.pyplot as plt

# %%
labels = final_data['Year'].unique()
values = final_data['Year'].value_counts(ascending=True)

fig, ax1 = plt.subplots(figsize=(8, 8))

ax1.pie(values, labels=labels, colors=['#42a7f5', '#d400ad'], autopct='%1.1f%%')
ax1.set(title='Ratio of population Distribution')
fig.suptitle('Population distribution based on Year', fontsize=30)
plt.legend()
plt.show()

# %% [markdown]
# **Weather condition**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'Year' is in string format
final_data['Year'] = pd.to_datetime(final_data['Year'], format='%Y')

# Increase figure size
plt.figure(figsize=(12, 6))

# Time Series Plot for Road Accidents, Injuries, and Fatalities
sns.lineplot(data=final_data, x='Year', y='Total_Accidents_roadtype', label='Total Accidents')
sns.lineplot(data=final_data, x='Year', y='Total_injured_roadtype', label='Total Injuries')
sns.lineplot(data=final_data, x='Year', y='Total_Killed_roadtype', label='Total Killed')

#plt.title('Road Accidents, Injuries, and Fatalities Over the Years')
plt.suptitle('Time Series Plot for Road Accidents, Injuries, and Fatalities based on roadtype', fontsize=15)
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'weather_condition' is a categorical column
fatalities_by_weather = final_data.groupby('weather_condition')['Total_Persons_killed'].sum()

# Set figure size before creating the pie chart
plt.figure(figsize=(10, 10))

plt.pie(fatalities_by_weather, labels=fatalities_by_weather.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Total killed by Weather Condition')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'Year' is a datetime column
final_data['Year'] = pd.to_datetime(final_data['Year'], format='%Y').dt.year



# Group data by Year and sum the injuries and fatalities
injuries_by_year = final_data.groupby('Year')['Total_Persons_Injured'].sum()
fatalities_by_year = final_data.groupby('Year')['Total_Persons_killed'].sum()

# Set up the figure and axes
plt.figure(figsize=(12, 6))

# Line plot for Injuries
plt.subplot(1, 2, 1)
sns.lineplot(x=injuries_by_year.index, y=injuries_by_year, marker='o', label='Injuries')
plt.title('Total killed Over the Years')
plt.xlabel('Year')
plt.ylabel('Total killed')
plt.xticks(rotation=45)
plt.legend()

# Line plot for Fatalities
plt.subplot(1, 2, 2)
sns.lineplot(x=fatalities_by_year.index, y=fatalities_by_year, marker='o', color='red', label='killed')
plt.title('Total killed Over the Years')
plt.xlabel('Year')
plt.ylabel('Total killed')
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Dividing the states into Zones**

# %%
north_india = ['Jammu & Kashmir', 'Punjab', 'Himachal Pradesh', 'Haryana', 'Uttarakhand', 'Uttar Pradesh', 'Chandigarh', 'Jammu and Kashmir', 'Delhi']
east_india = ['Bihar', 'Odisha', 'Jharkhand', 'West Bengal', 'Orissa']
south_india = ['Andhra Pradesh', 'Karnataka', 'Kerala' ,'Tamil Nadu', 'Telangana']
west_india = ['Rajasthan' , 'Gujarat', 'Goa','Maharashtra','Goa']
central_india = ['Madhya Pradesh', 'Chhattisgarh']
north_east_india = ['Assam', 'Sikkim', 'Nagaland', 'Meghalaya', 'Manipur', 'Mizoram', 'Tripura', 'Arunachal Pradesh']
ut_india = ['Andaman and Nicobar Islands', 'Dadra and Nagar Haveli', 'Puducherry', 'Andaman & Nicobar Islands', 'Dadra & Nagar Haveli', 'Daman & Diu', 'Lakshadweep', 'A & N Islands', 'D & N Haveli']

# %%
def get_zonal_names(row):
    if row['States/UTs'].strip() in north_india:
        val = 'North_Zone'
    elif row['States/UTs'].strip()  in south_india:
        val = 'South_Zone'
    elif row['States/UTs'].strip()  in east_india:
        val = 'East_Zone'
    elif row['States/UTs'].strip()  in west_india:
        val = 'West_Zone'
    elif row['States/UTs'].strip()  in central_india:
        val = 'Central_Zone'
    elif row['States/UTs'].strip()  in north_east_india:
                val = 'NE_Zone'
    elif row['States/UTs'].strip()  in ut_india:
        val = 'Union_Terr'
    else:
        val = 'No_Value'
    return val

# %%
road_type.rename({'State/ UT':'States/UTs'},axis=1,inplace=True)

# %%
weather.rename({'State/ UT':'States/UTs'},axis=1,inplace=True)

# %%
final_data.drop(final_data[final_data['States/UTs'] == 'Total'].index, inplace=True)
final_data['Zones'] = final_data.apply(get_zonal_names, axis=1)

# %%
final_data.columns
# Out:
# Index(['States/UTs', 'Total_injured_roadtype', 'Year', 'Road_type',
#        'Total_Killed_roadtype', 'Total_Accidents_roadtype',
#        'Total_killed_Accidents_weather', 'weather_condition',
#        'Total_Persons_Injured_weather', 'Total_Total_Accidents_weather',
#        'Total_Persons_Injured', 'Total_population', 'Total_Persons_killed',
#        'Zones'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 5))

# Create a bar plot
sns.barplot(x='Zones', y='Total_population', data=final_data)
plt.xlabel('Zones')
plt.ylabel('Total Population')
plt.title('Total Population by Zone')
plt.xticks(rotation=90, fontsize=10) 
plt.show()

# %%
plt.figure(figsize=(15, 5))
# Create a bar plot
sns.barplot(x='Zones', y='Total_Persons_killed', data=final_data)
plt.xlabel('Zones')
plt.ylabel('Total persons killed')
plt.title('Total persons killed by Zone')
plt.xticks(rotation=90, fontsize=10) 
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x='Zones', y='Total_Persons_Injured', data=final_data)
plt.xlabel('Zones')
plt.ylabel('Total persons injured')
plt.title('Total persons injured by Zone')
plt.xticks(rotation=90, fontsize=10) 
plt.show()

# %%
# Calculate total accidents
final_data['total_accidents'] = final_data['Total_killed_Accidents_weather'] + final_data['Total_Accidents_roadtype']

# Set the figure size
plt.figure(figsize=(15, 5))

# Create a bar plot
sns.barplot(x='Zones', y='total_accidents', data=final_data)
plt.xlabel('Zones')
plt.ylabel('Total Accidents')
plt.title('Total Accidents by Zone')
plt.xticks(rotation=90, fontsize=10)
plt.show()

# %%
# Assuming 'total_population' is the column you want to include
sub_df = final_data[final_data['Zones'] == 'South_Zone']
df = pd.pivot_table(sub_df, index=['States/UTs'], values=['Total_Persons_killed'], aggfunc=np.sum).reset_index()
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='States/UTs', y='Total_Persons_killed', data=df, ax=ax, color='pink')
plt.ylabel('Total_Persons_killed')
plt.title('Southern States Total_Persons_killed', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
df.head()
# Out:
#        States/UTs  Total_Persons_killed
# 0  Andhra Pradesh               3013920
# 1       Karnataka               3973536
# 2          Kerala               1537656
# 3      Tamil Nadu               5841232
# 4       Telangana               2616688

# %%
sub_df = final_data[final_data['Zones'] == 'South_Zone']
df = pd.pivot_table(sub_df, index=['States/UTs'], values=['Total_Persons_Injured'], aggfunc=np.sum).reset_index()
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='States/UTs', y='Total_Persons_Injured', data=df, ax=ax, color='skyblue')
plt.ylabel('Total_Persons_Injured')
plt.title('Southern States Total_Persons_Injured', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
sub_df = final_data[final_data['Zones'] == 'South_Zone']
df = pd.pivot_table(sub_df, index=['States/UTs'], values=['total_accidents'], aggfunc=np.sum).reset_index()
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='States/UTs', y='total_accidents', data=df, ax=ax, color='lightgreen')
plt.ylabel('total_accidents')
plt.title('Southern States total_accidents', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
df.head()
# Out:
#        States/UTs  total_accidents
# 0  Andhra Pradesh        2045824.0
# 1       Karnataka        3536481.0
# 2          Kerala        2805162.0
# 3      Tamil Nadu        5445002.0
# 4       Telangana        1711054.0

# %%
sub_df = final_data[final_data['States/UTs'] == 'Tamil Nadu']
df = pd.pivot_table(sub_df, index=['States/UTs', 'Road_type'], values=['Total_Accidents_roadtype'], aggfunc=np.sum).reset_index()

fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='Road_type', y='Total_Accidents_roadtype', data=df, ax=ax, color='purple')

plt.ylabel('Total Accidents')
plt.title('Total Accidents based on Road Type in Tamil Nadu', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

plt.show()

# %%
sub_df = final_data[final_data['States/UTs'] == 'Tamil Nadu']
df = pd.pivot_table(sub_df, index=['States/UTs', 'Road_type'], values=['Total_Killed_roadtype'], aggfunc=np.sum).reset_index()

fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='Road_type', y='Total_Killed_roadtype', data=df, ax=ax, color='purple')

plt.ylabel('Total_Killed_roadtype')
plt.title('Total_Killed  based on Road Type in Tamil Nadu', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

plt.show()

# %% [markdown]
# #####

# %%
sub_df = final_data[final_data['States/UTs'] == 'Tamil Nadu']
df = pd.pivot_table(sub_df, index=['States/UTs', 'Road_type'], values=['Total_injured_roadtype'], aggfunc=np.sum).reset_index()

fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='Road_type', y='Total_injured_roadtype', data=df, ax=ax, color='purple')

plt.ylabel('Total_injured_roadtype')
plt.title('Total_injured_roadtype  based on Road Type in Tamil Nadu', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

plt.show()

# %% [markdown]
# # Weather condition

# %%
sub_df1 = final_data[final_data['States/UTs'] == 'Tamil Nadu']
df = pd.pivot_table(sub_df1, index=['States/UTs', 'weather_condition'], values=['Total_Persons_Injured_weather'], aggfunc=np.sum).reset_index()

fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='weather_condition', y='Total_Persons_Injured_weather', data=df, ax=ax, color='blue')

plt.ylabel('Total persons injured based on the weather')
plt.title('Total injured  based on weather condition in Tamil Nadu', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

plt.show()

# %%
sub_df1 = final_data[final_data['States/UTs'] == 'Tamil Nadu']
df = pd.pivot_table(sub_df1, index=['States/UTs', 'weather_condition'], values=['Total_Total_Accidents_weather'], aggfunc=np.sum).reset_index()

fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='weather_condition', y='Total_Total_Accidents_weather', data=df, ax=ax, color='blue')

plt.ylabel('Total accidents based on the weather')
plt.title('Total accidents  based on weather condition in Tamil Nadu', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

plt.show()

# %%
sub_df1 = final_data[final_data['States/UTs'] == 'Tamil Nadu']
df = pd.pivot_table(sub_df1, index=['States/UTs', 'weather_condition'], values=['Total_killed_Accidents_weather'], aggfunc=np.sum).reset_index()

fig, ax = plt.subplots(1, 1, figsize=(20, 10))
sns.barplot(x='weather_condition', y='Total_killed_Accidents_weather', data=df, ax=ax, color='blue')

plt.ylabel('Total killed based on the weather')
plt.title('Total killed  based on weather condition in Tamil Nadu', fontsize=15)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability

plt.show()

# %%
final_data.columns
# Out:
# Index(['States/UTs', 'Total_injured_roadtype', 'Year', 'Road_type',
#        'Total_Killed_roadtype', 'Total_Accidents_roadtype',
#        'Total_killed_Accidents_weather', 'weather_condition',
#        'Total_Persons_Injured_weather', 'Total_Total_Accidents_weather',
#        'Total_Persons_Injured', 'Total_population', 'Total_Persons_killed',
#        'Zones', 'total_accidents'],
#       dtype='object')
